# %% [markdown]
# #### To use the Random Forest Survival analysis you will need to use the Pysurvival package.
# To install this package please follow the instructions from this site https://square.github.io/pysurvival/installation.html
# ##### For MacOS users:
# You will need to add two more lines besides the recommended 2 as shown below:
# ###### Note: please check which version of gcc do you have as it might be different from 9.3.0.

# %% [raw]
# export CC=/usr/local/Cellar/gcc/9.3.0/bin/gcc-9
# export CXX=/usr/local/Cellar/gcc/9.3.0/bin/g++-9
# export DYLD_LIBRARY_PATH=/usr/local/Cellar/gcc/9.3.0/lib/gcc/9/:$DYLD_LIBRARY_PATH
# export LD_LIBRARY_PATH=/usr/local/Cellar/gcc/9.3.0/lib/gcc/9/:$LD_LIBRARY_PATH

# %% [markdown]
# ### To use the Random Forest Survival analysis we need to load the data and remove the colinear features

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
sns.set()
from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# %% [markdown]
# ### using the panda reader import your file where the data is contained

# %%
clinical_data=pd.read_excel('WithoutMRNEndometrial_TextureFeatures_09182019.xlsx')
other_data=pd.read_excel('1.20.20 DeIdentified_HG_CT_JJM_AS_Clinical Variables_Final.xlsx')

other_data
# Out:
#      De-Identified Study ID ExamStatus Tumor Visible          CT_Make  CT_ST  \
# 0                         1          F             Y   Light Speed 16    5.0
# 1                         2          F             Y  Light Speed VCT    5.0
# 2                         3          F             Y   Light Speed 16    5.0
# 3                         4          F             Y  Discovery CT750    5.0
# 4                         5          F             Y   Light Speed 16    5.0
# ..                      ...        ...           ...              ...    ...
# 152                     153          F             Y  Light Speed VCT    5.0
# 153                     154          F             Y   Revolution GSI    5.0
# 154                     155          F             Y  Light Speed VCT    5.0
# 155                     156          F             Y  Discovery CT750    5.0
# 156                     157          F             Y    Revolution HD    5.0
#
#      CT_kVp  CT_mA  CT_Pitch  Age at Dx  Race  ...  \
# 0     120.0  360.0     1.375         69   1.0  ...
# 1     120.0  219.0     0.984         71   2.0  ...
# 2     120.0  380.0     1.375         55   0.0  ...
# 3     120.0  227.0     0.984         61   0.0  ...
# 4     120.0  440.0     0.938         79   NaN  ...
# ..      ...    ...       ...        ...   ...  ...
# 152   120.0  309.0     0.984         64   0.0  ...
# 153   120.0  219.0     0.984         73   2.0  ...
# 154   120.0  219.0     0.984         70   2.0  ...
# 155   120.0  379.0     0.984         68   0.0  ...
# 156   140.0  375.0     0.984         66   0.0  ...
#
#      Time to Recurrence (months)  \
# 0                      72.866667
# 1                      57.733333
# 2                      69.100000
# 3                      39.233333
# 4                            NaN
# ..                           ...
# 152                    22.400000
# 153                     8.266667
# 154                    18.666667
# 155                    20.300000
# 156                    19.966667
#
#      Pt recurred prior to 18 months (0=no 1= yes)  Deceased (y/n)  \
# 0                                             NaN             0.0
# 1                                             NaN             0.0
# 2                                             NaN             0.0
# 3                                             NaN             0.0
# 4                                             NaN             NaN
# ..                                            ...             ...
# 152                                           NaN             0.0
# 153                                           1.0             0.0
# 154                                           NaN             0.0
# 155                                           NaN             0.0
# 156                                           NaN             0.0
#
#      Overall Survival (Months)  Reason for excluxion  Comments  Unnamed: 27  \
# 0                    72.866667                   NaN       NaN          NaN
# 1                    57.733333                   NaN       NaN          NaN
# 2                    69.100000                   NaN       NaN          NaN
# 3                    39.233333                   NaN       NaN          NaN
# 4                          NaN  cannot see the tumor       NaN          NaN
# ..                         ...                   ...       ...          ...
# 152                  22.400000                   NaN       NaN          NaN
# 153                  24.933333                   NaN       NaN          NaN
# 154                  18.666667                   NaN       NaN          NaN
# 155                  20.300000                   NaN       NaN          NaN
# 156                  19.966667                   NaN       NaN          NaN
#
#      Unnamed: 28  Unnamed: 29  Unnamed: 30
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# 2            NaN          NaN          NaN
# 3            NaN          NaN          NaN
# 4            NaN          NaN
# ..           ...          ...          ...
# 152          NaN          NaN          NaN
# 153          NaN          NaN          NaN
# 154          NaN          NaN          NaN
# 155          NaN          NaN          NaN
# 156          NaN          NaN          NaN
#
# [157 rows x 31 columns]

# %%
# it is always good idea to have some idea how your data looks like
clinical_data
# Out:
#      De identified Study ID     GLCM1     GLCM2     GLCM3     GLCM4     GLCM5  \
# 0                         1  0.026256  4.333412  0.449950  3.917603  0.454955
# 1                         2  0.050280  2.314190  0.484697  2.424970  0.537827
# 2                         3  0.023361  5.228412  0.398057  4.528518  0.411689
# 3                         4  0.039554  1.855517  0.711033  3.394799  0.580393
# 4                         5       NaN       NaN       NaN       NaN       NaN
# ..                      ...       ...       ...       ...       ...       ...
# 152                     153  0.030961  3.329703  0.451058  3.087595  0.476773
# 153                     154  0.029211  3.481393  0.501623  3.940367  0.474784
# 154                     155  0.035093  2.847245  0.527364  3.044318  0.511396
# 155                     156  0.033468  1.997960  0.713680  3.649665  0.556493
# 156                     157  0.031904  3.066638  0.531499  3.368266  0.483350
#
#          GLCM6      GLCM7     GLCM8     GLCM9  ...    ACM2_10   ACM2_11  \
# 0    18.285737  11.337002  3.752016  5.716646  ...   8.721173  2.940614
# 1    17.646685   7.385692  3.347634  4.862031  ...  13.201337  3.010564
# 2    14.291180  12.885660  3.826931  5.966786  ...  15.510645  3.415731
# 3    17.935818  11.723678  3.712137  5.129299  ...  10.880541  2.965569
# 4          NaN        NaN       NaN       NaN  ...        NaN       NaN
# ..         ...        ...       ...       ...  ...        ...       ...
# 152  18.400621   9.020677  3.600778  5.457496  ...  13.744894  3.237901
# 153  12.609427  12.280073  3.721832  5.599860  ...  12.915139  3.192640
# 154  16.492182   9.330027  3.623143  5.368373  ...  17.301398  3.374493
# 155  16.244867  12.600701  3.835563  5.356900  ...  15.174270  3.351991
# 156  18.492018  10.406424  3.688363  5.450180  ...  14.287299  3.317053
#
#       ACM2_12   ACM2_13   ACM2_14    ACM2_15      ACM2_16       ACM2_17  \
# 0   -0.148826  0.818354  0.593029  15.073033  1589.851794  25079.738554
# 1   -0.199530  0.884071  0.685592  22.045709  1375.243100  22262.287867
# 2   -0.087748  0.692718  0.457665  29.858372  1154.498568  18661.617962
# 3   -0.170623  0.851561  0.672977  17.817663  1262.648674  20244.421621
# 4         NaN       NaN       NaN        NaN          NaN           NaN
# ..        ...       ...       ...        ...          ...           ...
# 152 -0.117999  0.762980  0.544010  24.375379  1216.030259  19845.283280
# 153 -0.128645  0.762071  0.644287  22.532088  1229.523023  18864.092413
# 154 -0.104464  0.734452  0.527287  31.631916  1131.817162  19269.673532
# 155 -0.091512  0.711624  0.492463  27.887957  1324.578843  21823.254109
# 156 -0.117197  0.768931  0.535616  26.693202  1240.599985  19581.380291
#
#       ACM2_18   ACM2_19
# 0    4.739398  0.986655
# 1    4.737088  0.986307
# 2    5.744309  0.992419
# 3    4.899353  0.986331
# 4         NaN       NaN
# ..        ...       ...
# 152  5.463958  0.990320
# 153  2.946259  0.955650
# 154  5.463295  0.991081
# 155  5.910660  0.992627
# 156  5.571727  0.990972
#
# [157 rows x 256 columns]

# %%
# in this data sets certain rows are excluded so we have to remove them 
data=clinical_data.drop([4, 7, 11, 13, 23, 25, 29, 36, 41, 47, 61, 62, 63, 68, 76, 88, 94, 96, 
                          108, 133, 135, 142]).reset_index(drop=True)
o_data=other_data.drop([4,7, 11, 13, 23, 25, 29, 36, 41, 47, 61, 62, 63, 68, 76, 88, 94, 96, 
                          108, 133, 135, 142]).reset_index(drop=True)
o_data
data.columns
# Out:
# Index(['De identified Study ID', 'GLCM1', 'GLCM2', 'GLCM3', 'GLCM4', 'GLCM5',
#        'GLCM6', 'GLCM7', 'GLCM8', 'GLCM9',
#        ...
#        'ACM2_10', 'ACM2_11', 'ACM2_12', 'ACM2_13', 'ACM2_14', 'ACM2_15',
#        'ACM2_16', 'ACM2_17', 'ACM2_18', 'ACM2_19'],
#       dtype='object', length=256)

# %%
data['time column']=o_data['Time to Recurrence (months)']
data['event column']=o_data['Recurrence (y/n)']

# %%
data1=data.drop(columns=['De identified Study ID'])
data1.to_csv('for_survival.csv')

# %%
lola=data1.iloc[:,0:255]
lola.columns
# Out:
# Index(['GLCM1', 'GLCM2', 'GLCM3', 'GLCM4', 'GLCM5', 'GLCM6', 'GLCM7', 'GLCM8',
#        'GLCM9', 'GLCM10',
#        ...
#        'ACM2_10', 'ACM2_11', 'ACM2_12', 'ACM2_13', 'ACM2_14', 'ACM2_15',
#        'ACM2_16', 'ACM2_17', 'ACM2_18', 'ACM2_19'],
#       dtype='object', length=255)

# %%
time_column='time column'
event_column='event column'
features=np.setdiff1d(data1.columns, [time_column, event_column]).tolist()
len(features)
# Out:
# 255

# %% [markdown]
# ### We will be using Variance Inflation Factor to remove the colinear features
# In the RFS analysis it is very important to remove the colinear features

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor    

def calculate_vif_(X, thresh=20.0):
    variables = list(range(X.shape[1]))
    dropped = True
    while dropped:
        dropped = False
        vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X.iloc[:, variables].columns[maxloc] +
                  '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped = True

    print('Remaining variables:')
    print(X.columns[variables])
    return X.iloc[:, variables]

# %%
#VIF of 10 means that all the features with R^2 above 0.9 will removed
X=lola
calculate_vif_(X, 10)
# Out:
# dropping 'GLCM1' at index: 0
# dropping 'GLCM2' at index: 0
# dropping 'GLCM3' at index: 0
# dropping 'GLCM4' at index: 0
# dropping 'GLCM5' at index: 0
# dropping 'GLCM6' at index: 0
# dropping 'GLCM7' at index: 0
# dropping 'GLCM8' at index: 0
# dropping 'GLCM9' at index: 0
# dropping 'GLCM10' at index: 0
# dropping 'GLCM11' at index: 0
# dropping 'GLCM12' at index: 0
# dropping 'GLCM13' at index: 0
# dropping 'GLCM14' at index: 0
# dropping 'GLCM15' at index: 0
# dropping 'GLCM16' at index: 0
# dropping 'GLCM17' at index: 0
# dropping 'GLCM18' at index: 0
# dropping 'GLCM19' at index: 0
# dropping 'RLM1' at index: 0
# dropping 'RLM2' at index: 0
# dropping 'RLM3' at index: 0
# dropping 'RLM4' at index: 0
# dropping 'RLM5' at index: 0
# dropping 'RLM6' at index: 0
# dropping 'RLM7' at index: 0
# dropping 'RLM8' at index: 0
# dropping 'RLM9' at index: 0
# dropping 'RLM10' at index: 0
# dropping 'RLM11' at index: 0
# dropping 'IH1' at index: 0
# dropping 'IH2' at index: 0
# dropping 'IH3' at index: 0
# dropping 'IH4' at index: 0
# dropping 'IH5' at index: 0
# dropping 'LBP1' at index: 0
# dropping 'LBP2' at index: 0
# dropping 'LBP3' at index: 0
# dropping 'LBP4' at index: 0
# dropping 'LBP5' at index: 0
# dropping 'LBP6' at index: 0
# dropping 'LBP7' at index: 0
# dropping 'LBP8' at index: 0
# dropping 'LBP9' at index: 0
# dropping 'LBP10' at index: 0
# dropping 'LBP11' at index: 0
# dropping 'LBP12' at index: 0
# dropping 'LBP13' at index: 0
# dropping 'LBP14' at index: 0
# dropping 'LBP15' at index: 0
# dropping 'LBP16' at index: 0
# dropping 'LBP17' at index: 0
# dropping 'LBP18' at index: 0
# dropping 'LBP19' at index: 0
# dropping 'LBP20' at index: 0
# dropping 'LBP21' at index: 0
# dropping 'LBP22' at index: 0
# dropping 'LBP23' at index: 0
# dropping 'LBP24' at index: 0
# dropping 'LBP25' at index: 0
# dropping 'LBP26' at index: 0
# dropping 'LBP27' at index: 0
# dropping 'LBP28' at index: 0
# dropping 'LBP29' at index: 0
# dropping 'LBP30' at index: 0
# dropping 'LBP31' at index: 0
# dropping 'LBP32' at index: 0
# dropping 'LBP33' at index: 0
# dropping 'LBP34' at index: 0
# dropping 'LBP35' at index: 0
# dropping 'LBP36' at index: 0
# dropping 'LBP37' at index: 0
# dropping 'LBP38' at index: 0
# dropping 'LBP39' at index: 0
# dropping 'LBP40' at index: 0
# dropping 'LBP41' at index: 0
# dropping 'LBP42' at index: 0
# dropping 'LBP43' at index: 0
# dropping 'LBP44' at index: 0
# dropping 'LBP45' at index: 0
# dropping 'LBP46' at index: 0
# dropping 'LBP47' at index: 0
# dropping 'LBP48' at index: 0
# dropping 'LBP49' at index: 0
# dropping 'LBP50' at index: 0
# dropping 'LBP51' at index: 0
# dropping 'LBP52' at index: 0
# dropping 'LBP53' at index: 0
# dropping 'LBP54' at index: 0
# dropping 'LBP55' at index: 0
# dropping 'LBP56' at index: 0
# dropping 'LBP57' at index: 0
# dropping 'LBP58' at index: 0
# dropping 'LBP59' at index: 0
# dropping 'LBP60' at index: 0
# dropping 'LBP61' at index: 0
# dropping 'LBP62' at index: 0
# dropping 'LBP63' at index: 0
# dropping 'LBP64' at index: 0
# dropping 'LBP65' at index: 0
# dropping 'LBP66' at index: 0
# dropping 'LBP67' at index: 0
# dropping 'LBP68' at index: 0
# dropping 'LBP69' at index: 0
# dropping 'LBP70' at index: 0
# dropping 'LBP71' at index: 0
# dropping 'LBP72' at index: 0
# dropping 'LBP74' at index: 1
# dropping 'LBP73' at index: 0
# dropping 'LBP75' at index: 0
# dropping 'LBP77' at index: 1
# dropping 'LBP79' at index: 2
# dropping 'LBP76' at index: 0
# dropping 'LBP80' at index: 1
# dropping 'ACM1_1' at index: 103
# dropping 'ACM1_2' at index: 103
# dropping 'ACM1_4' at index: 104
# dropping 'ACM2_2' at index: 120
# dropping 'ACM2_4' at index: 121
# dropping 'ACM2_1' at index: 119
# dropping 'LBP78' at index: 0
# dropping 'LBP121' at index: 40
# dropping 'LBP122' at index: 40
# dropping 'ACM2_8' at index: 120
# dropping 'ACM1_8' at index: 104
# dropping 'FD24' at index: 69
# dropping 'FD14' at index: 59
# dropping 'ACM1_11' at index: 104
# dropping 'FD20' at index: 64
# dropping 'ACM2_19' at index: 125
# dropping 'ACM1_9' at index: 101
# dropping 'FD41' at index: 83
# dropping 'ACM1_16' at index: 105
# dropping 'FD17' at index: 61
# dropping 'FD10' at index: 55
# dropping 'FD35' at index: 75
# dropping 'LBP123' at index: 40
# dropping 'ACM2_6' at index: 106
# dropping 'FD11' at index: 54
# dropping 'FD13' at index: 55
# dropping 'FD47' at index: 82
# dropping 'ACM2_11' at index: 106
# dropping 'ACM1_6' at index: 91
# dropping 'FD38' at index: 74
# dropping 'FD7' at index: 51
# dropping 'FD8' at index: 51
# dropping 'FD16' at index: 54
# dropping 'ACM1_19' at index: 95
# dropping 'FD21' at index: 56
# dropping 'FD32' at index: 65
# dropping 'ACM1_15' at index: 90
# dropping 'FD44' at index: 73
# dropping 'FD52' at index: 79
# dropping 'LBP126' at index: 42
# dropping 'FD19' at index: 54
# dropping 'FD4' at index: 47
# dropping 'FD5' at index: 47
# dropping 'ACM2_10' at index: 90
# dropping 'ACM2_9' at index: 89
# dropping 'ACM2_5' at index: 87
# dropping 'ACM2_13' at index: 89
# dropping 'FD12' at index: 49
# dropping 'LBP125' at index: 41
# dropping 'FD18' at index: 49
# dropping 'FD29' at index: 55
# dropping 'ACM2_16' at index: 87
# dropping 'ACM1_10' at index: 76
# dropping 'FD53' at index: 71
# dropping 'FD37' at index: 60
# dropping 'LBP124' at index: 40
# dropping 'ACM2_7' at index: 79
# dropping 'FD31' at index: 55
# dropping 'FD34' at index: 56
# dropping 'FD49' at index: 64
# dropping 'FD1' at index: 42
# dropping 'ACM1_14' at index: 71
# dropping 'ACM1_5' at index: 67
# dropping 'LBP128' at index: 41
# dropping 'ACM1_17' at index: 69
# dropping 'FD9' at index: 44
# dropping 'FD46' at index: 59
# dropping 'FD23' at index: 46
# dropping 'FD40' at index: 54
# dropping 'LBP85' at index: 4
# dropping 'ACM2_14' at index: 67
# dropping 'FD28' at index: 48
# dropping 'ACM1_7' at index: 60
# dropping 'FD2' at index: 40
# dropping 'FD6' at index: 41
# dropping 'ACM1_18' at index: 60
# dropping 'LBP81' at index: 0
# dropping 'FD43' at index: 50
# dropping 'ACM2_3' at index: 58
# dropping 'LBP83' at index: 1
# dropping 'FD33' at index: 45
# dropping 'FD50' at index: 50
# dropping 'FD39' at index: 46
# dropping 'LBP82' at index: 0
# dropping 'FD36' at index: 44
# dropping 'LBP95' at index: 10
# dropping 'LBP98' at index: 12
# dropping 'FD15' at index: 36
# dropping 'LBP87' at index: 2
# dropping 'ACM2_18' at index: 51
# dropping 'FD22' at index: 35
# dropping 'ACM1_13' at index: 46
# dropping 'FD42' at index: 39
# dropping 'ACM2_17' at index: 47
# dropping 'LBP84' at index: 0
# dropping 'FD3' at index: 33
# dropping 'LBP93' at index: 6
# dropping 'LBP114' at index: 24
# dropping 'LBP88' at index: 1
# dropping 'ACM2_15' at index: 41
# dropping 'ACM1_3' at index: 38
# dropping 'LBP96' at index: 6
# dropping 'LBP113' at index: 21
# dropping 'FD45' at index: 32
# dropping 'FD26' at index: 29
# dropping 'LBP109' at index: 17
# dropping 'LBP91' at index: 3
# dropping 'FD30' at index: 28
# dropping 'LBP105' at index: 12
# dropping 'LBP100' at index: 7
# dropping 'LBP110' at index: 14
# dropping 'LBP127' at index: 22
# dropping 'LBP111' at index: 14
# dropping 'FD25' at index: 21
# dropping 'LBP117' at index: 17
# dropping 'LBP104' at index: 10
# dropping 'LBP89' at index: 1
# dropping 'ACM2_12' at index: 23
# dropping 'LBP97' at index: 4
# dropping 'LBP115' at index: 12
# dropping 'LBP99' at index: 4
# dropping 'FD48' at index: 16
# dropping 'LBP103' at index: 6
# dropping 'LBP86' at index: 0
# dropping 'LBP90' at index: 0
# dropping 'LBP102' at index: 3
# dropping 'LBP92' at index: 0
# Remaining variables:
# Index(['LBP94', 'LBP101', 'LBP106', 'LBP107', 'LBP108', 'LBP112', 'LBP116',
#        'LBP118', 'LBP119', 'LBP120', 'FD27', 'FD51', 'FD54', 'ACM1_12'],
#       dtype='object')
#         LBP94    LBP101    LBP106    LBP107    LBP108    LBP112    LBP116  \
# 0    0.008640  0.013356  0.004859  0.004859  0.004132  0.000000  0.010616
# 1    0.007668  0.048193  0.000000  0.004474  0.002237  0.002237  0.022017
# 2    0.021092  0.012521  0.004832  0.004832  0.002381  0.002381  0.010747
# 3    0.016198  0.010369  0.000418  0.000418  0.002021  0.001185  0.009453
# 4    0.009955  0.005240  0.002404  0.002404  0.000000  0.000000  0.014629
# ..        ...       ...       ...       ...       ...       ...       ...
# 130  0.022039  0.010716  0.003116  0.003159  0.003084  0.002702  0.008869
# 131  0.012268  0.011711  0.001980  0.002713  0.001017  0.000758  0.006853
# 132  0.015814  0.010354  0.001611  0.003510  0.000773  0.000773  0.008804
# 133  0.019432  0.016423  0.002315  0.002550  0.001315  0.000583  0.009172
# 134  0.038723  0.027362  0.002442  0.002442  0.000000  0.000000  0.008527
#
#        LBP118    LBP119    LBP120       FD27      FD51      FD54   ACM1_12
# 0    0.007653  0.002066  0.000000   9.000000  0.079923  0.068974 -0.072218
# 1    0.025663  0.002237  0.002268   3.333333  0.128958  0.112149 -0.128768
# 2    0.013208  0.000456  0.000000  15.250000  0.056418  0.044223 -0.044774
# 3    0.017735  0.000000  0.001094  15.750000  0.141440  0.121297 -0.076017
# 4    0.011696  0.004484  0.000000   8.000000  0.157050  0.145854 -0.071011
# ..        ...       ...       ...        ...       ...       ...       ...
# 130  0.014814  0.000392  0.000713  24.500000  0.087100  0.067616 -0.051001
# 131  0.014726  0.001896  0.000630  25.888889  0.055196  0.037529 -0.155972
# 132  0.009672  0.002337  0.000396  31.714286  0.100156  0.067450 -0.041698
# 133  0.014753  0.000963  0.000259  59.888889  0.112976  0.065836 -0.032100
# 134  0.007136  0.004505  0.000000   8.333333  0.100414  0.092534 -0.060737
#
# [135 rows x 14 columns]

# %%
#creating a new dataframe with colinear features removed
data2=data1.loc[:, ['LBP94', 'LBP101', 'LBP106', 'LBP107', 'LBP108', 'LBP112', 'LBP116',
       'LBP118', 'LBP119', 'LBP120', 'FD27', 'FD51', 'FD54', 'ACM1_12', 'time column', 'event column']]
data2
# Out:
#         LBP94    LBP101    LBP106    LBP107    LBP108    LBP112    LBP116  \
# 0    0.008640  0.013356  0.004859  0.004859  0.004132  0.000000  0.010616
# 1    0.007668  0.048193  0.000000  0.004474  0.002237  0.002237  0.022017
# 2    0.021092  0.012521  0.004832  0.004832  0.002381  0.002381  0.010747
# 3    0.016198  0.010369  0.000418  0.000418  0.002021  0.001185  0.009453
# 4    0.009955  0.005240  0.002404  0.002404  0.000000  0.000000  0.014629
# ..        ...       ...       ...       ...       ...       ...       ...
# 130  0.022039  0.010716  0.003116  0.003159  0.003084  0.002702  0.008869
# 131  0.012268  0.011711  0.001980  0.002713  0.001017  0.000758  0.006853
# 132  0.015814  0.010354  0.001611  0.003510  0.000773  0.000773  0.008804
# 133  0.019432  0.016423  0.002315  0.002550  0.001315  0.000583  0.009172
# 134  0.038723  0.027362  0.002442  0.002442  0.000000  0.000000  0.008527
#
#        LBP118    LBP119    LBP120       FD27      FD51      FD54   ACM1_12  \
# 0    0.007653  0.002066  0.000000   9.000000  0.079923  0.068974 -0.072218
# 1    0.025663  0.002237  0.002268   3.333333  0.128958  0.112149 -0.128768
# 2    0.013208  0.000456  0.000000  15.250000  0.056418  0.044223 -0.044774
# 3    0.017735  0.000000  0.001094  15.750000  0.141440  0.121297 -0.076017
# 4    0.011696  0.004484  0.000000   8.000000  0.157050  0.145854 -0.071011
# ..        ...       ...       ...        ...       ...       ...       ...
# 130  0.014814  0.000392  0.000713  24.500000  0.087100  0.067616 -0.051001
# 131  0.014726  0.001896  0.000630  25.888889  0.055196  0.037529 -0.155972
# 132  0.009672  0.002337  0.000396  31.714286  0.100156  0.067450 -0.041698
# 133  0.014753  0.000963  0.000259  59.888889  0.112976  0.065836 -0.032100
# 134  0.007136  0.004505  0.000000   8.333333  0.100414  0.092534 -0.060737
#
#      time column  event column
# 0      72.866667           0.0
# 1      57.733333           0.0
# 2      69.100000           0.0
# 3      39.233333           0.0
# 4      20.000000           1.0
# ..           ...           ...
# 130    22.400000           0.0
# 131     8.266667           1.0
# 132    18.666667           0.0
# 133    20.300000           0.0
# 134    19.966667           0.0
#
# [135 rows x 16 columns]

# %%
#create a dataframe with time and event columns
time_column='time column'
event_column='event column'
features=np.setdiff1d(data2.columns, [time_column, event_column]).tolist()
len(features)
features
data2
# Out:
#         LBP94    LBP101    LBP106    LBP107    LBP108    LBP112    LBP116  \
# 0    0.008640  0.013356  0.004859  0.004859  0.004132  0.000000  0.010616
# 1    0.007668  0.048193  0.000000  0.004474  0.002237  0.002237  0.022017
# 2    0.021092  0.012521  0.004832  0.004832  0.002381  0.002381  0.010747
# 3    0.016198  0.010369  0.000418  0.000418  0.002021  0.001185  0.009453
# 4    0.009955  0.005240  0.002404  0.002404  0.000000  0.000000  0.014629
# ..        ...       ...       ...       ...       ...       ...       ...
# 130  0.022039  0.010716  0.003116  0.003159  0.003084  0.002702  0.008869
# 131  0.012268  0.011711  0.001980  0.002713  0.001017  0.000758  0.006853
# 132  0.015814  0.010354  0.001611  0.003510  0.000773  0.000773  0.008804
# 133  0.019432  0.016423  0.002315  0.002550  0.001315  0.000583  0.009172
# 134  0.038723  0.027362  0.002442  0.002442  0.000000  0.000000  0.008527
#
#        LBP118    LBP119    LBP120       FD27      FD51      FD54   ACM1_12  \
# 0    0.007653  0.002066  0.000000   9.000000  0.079923  0.068974 -0.072218
# 1    0.025663  0.002237  0.002268   3.333333  0.128958  0.112149 -0.128768
# 2    0.013208  0.000456  0.000000  15.250000  0.056418  0.044223 -0.044774
# 3    0.017735  0.000000  0.001094  15.750000  0.141440  0.121297 -0.076017
# 4    0.011696  0.004484  0.000000   8.000000  0.157050  0.145854 -0.071011
# ..        ...       ...       ...        ...       ...       ...       ...
# 130  0.014814  0.000392  0.000713  24.500000  0.087100  0.067616 -0.051001
# 131  0.014726  0.001896  0.000630  25.888889  0.055196  0.037529 -0.155972
# 132  0.009672  0.002337  0.000396  31.714286  0.100156  0.067450 -0.041698
# 133  0.014753  0.000963  0.000259  59.888889  0.112976  0.065836 -0.032100
# 134  0.007136  0.004505  0.000000   8.333333  0.100414  0.092534 -0.060737
#
#      time column  event column
# 0      72.866667           0.0
# 1      57.733333           0.0
# 2      69.100000           0.0
# 3      39.233333           0.0
# 4      20.000000           1.0
# ..           ...           ...
# 130    22.400000           0.0
# 131     8.266667           1.0
# 132    18.666667           0.0
# 133    20.300000           0.0
# 134    19.966667           0.0
#
# [135 rows x 16 columns]

# %%
#visualize the correlation matrix
from pysurvival.utils.display import correlation_matrix
correlation_matrix(data2[features], figure_size=(30,15), text_fontsize=10)

# %% [markdown]
# #### Now we are ready to analyze our data
#  we need to define our input (X), time (T) and event (E) columns

# %%
# Creating the X, T and E inputs
X = data2[features]

newX=np.setdiff1d(data2.columns, [ event_column]).tolist()
X=data2[newX]
E=data2['event column']

# %% [markdown]
# ### Now we are ready to perform the random forest survival analysis
# #### In this example we are using the 10 Stratified Kfold and and evaluating the performance of each run by
# #### evaluating the concordance and plotting the predicted survival curve and error

# %%
#the random tree variables need to be fine tuned using loops because 
#the grid search CV is not compatible with the PySurvival package

from sklearn.model_selection import StratifiedKFold
from pysurvival.models.survival_forest import RandomSurvivalForestModel
from pysurvival.utils.metrics import concordance_index
from pysurvival.utils.display import compare_to_actual
from pysurvival.utils.display import integrated_brier_score
i=1
kf=StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
for train_index, test_index in kf.split(X,E):
    print('\n {} of kfold {}'.format(i,kf.n_splits)) 
    X1_train, X1_test=X.loc[train_index], X.loc[test_index]
    X_train, X_test=X1_train[features], X1_test[features]
    T_train, T_test=X1_train['time column'].values, X1_test['time column'].values
    E_train, E_test=E.loc[train_index].values, E.loc[test_index].values
    xst = RandomSurvivalForestModel(num_trees=10) 
    xst.fit(X_train, T_train, E_train, max_features = 'sqrt', max_depth = 1,
        min_node_size = 2, num_threads = -1, 
        sample_size_pct = 0.63, importance_mode = 'normalized_permutation',
        seed = None, save_memory=False )
    c_index = concordance_index(xst, X_test, T_test, E_test)
    print('C-index: {:.2f}'.format(c_index))
    results = compare_to_actual(xst, X_test, T_test, E_test, is_at_risk = True,  figure_size=(16, 6), 
                                metrics = ['rmse', 'mean', 'median'])
    ibs = integrated_brier_score(xst, X_test, T_test, E_test, t_max=100, figure_size=(15,5))
    print('IBS: {:.2f}'.format(ibs))
    i=i+1
# Out:
#  1 of kfold 10
# C-index: 0.69
# IBS: 0.18
#
#  2 of kfold 10
# C-index: 0.68
# IBS: 0.16
#
#  3 of kfold 10
# C-index: 0.76
# IBS: 0.15
#
#  4 of kfold 10
# C-index: 0.58
# IBS: 0.15
#
#  5 of kfold 10
# C-index: 0.58
# IBS: 0.15
#
#  6 of kfold 10
# C-index: 0.74
# IBS: 0.13
#
#  7 of kfold 10
# C-index: 0.65
# IBS: 0.11
#
#  8 of kfold 10
# C-index: 0.52
# IBS: 0.13
#
#  9 of kfold 10
# C-index: 0.83
# IBS: 0.17
#
#  10 of kfold 10
# C-index: 0.60
# IBS: 0.18

# %% [markdown]
# ### the importance table allows you to identify the main contributing features

# %%
xst.variable_importance_table.head(20)
#the results indicate that we only had 3 variables which were important features
# Out:
#     feature  importance  pct_importance
# 0      FD51    1.054093        0.182265
# 1    LBP101    1.054093        0.182265
# 2    LBP112    1.054093        0.182265
# 3    LBP116    1.054093        0.182265
# 4      FD54    0.974235        0.168456
# 5      FD27    0.592703        0.102485
# 6   ACM1_12    0.000000        0.000000
# 7    LBP106    0.000000        0.000000
# 8    LBP107    0.000000        0.000000
# 9    LBP108    0.000000        0.000000
# 10   LBP118    0.000000        0.000000
# 11   LBP119    0.000000        0.000000
# 12   LBP120    0.000000        0.000000
# 13    LBP94    0.000000        0.000000

# %%
data3=data2.loc[:, ['LBP94', 'LBP116',
       'FD51',, 'event column']]
data3
# Out:
#         LBP94    LBP116      FD51  time column  event column
# 0    0.008640  0.010616  0.079923    72.866667           0.0
# 1    0.007668  0.022017  0.128958    57.733333           0.0
# 2    0.021092  0.010747  0.056418    69.100000           0.0
# 3    0.016198  0.009453  0.141440    39.233333           0.0
# 4    0.009955  0.014629  0.157050    20.000000           1.0
# ..        ...       ...       ...          ...           ...
# 130  0.022039  0.008869  0.087100    22.400000           0.0
# 131  0.012268  0.006853  0.055196     8.266667           1.0
# 132  0.015814  0.008804  0.100156    18.666667           0.0
# 133  0.019432  0.009172  0.112976    20.300000           0.0
# 134  0.038723  0.008527  0.100414    19.966667           0.0
#
# [135 rows x 5 columns]

# %%
# Creating the X, T and E inputs
Xnew = data3[['LBP94', 'LBP116','FD51', 'time column']]
features2=['LBP94', 'LBP116','FD51']

Xnew[features2]
Enew=data3['event column']
Enew
Xnew['time column']
# Out:
# 0      72.866667
# 1      57.733333
# 2      69.100000
# 3      39.233333
# 4      20.000000
#          ...
# 130    22.400000
# 131     8.266667
# 132    18.666667
# 133    20.300000
# 134    19.966667
# Name: time column, Length: 135, dtype: float64

# %%
#the random tree variables need to be fine tuned using loops because 
#the grid search CV is not compatible with the PySurvival package

from sklearn.model_selection import StratifiedKFold
from pysurvival.models.survival_forest import RandomSurvivalForestModel
from pysurvival.utils.metrics import concordance_index
from pysurvival.utils.display import compare_to_actual
from pysurvival.utils.display import integrated_brier_score
i=1
kf=StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
for train_index, test_index in kf.split(Xnew,Enew):
    print('\n {} of kfold {}'.format(i,kf.n_splits)) 
    X1_train, X1_test=Xnew.loc[train_index], Xnew.loc[test_index]
    X_train, X_test=X1_train[features2], X1_test[features2]
    T_train, T_test=X1_train['time column'].values, X1_test['time column'].values
    E_train, E_test=Enew.loc[train_index].values, Enew.loc[test_index].values
    xst = RandomSurvivalForestModel(num_trees=10) 
    xst.fit(X_train, T_train, E_train, max_features = 'sqrt', max_depth = 1,
        min_node_size = 2, num_threads = -1, 
        sample_size_pct = 0.63, importance_mode = 'normalized_permutation',
        seed = None, save_memory=False )
    c_index = concordance_index(xst, X_test, T_test, E_test)
    print('C-index: {:.2f}'.format(c_index))
    results = compare_to_actual(xst, X_test, T_test, E_test, is_at_risk = True,  figure_size=(16, 6), 
                                metrics = ['rmse', 'mean', 'median'])
    ibs = integrated_brier_score(xst, X_test, T_test, E_test, t_max=100, figure_size=(15,5))
    print('IBS: {:.2f}'.format(ibs))
    i=i+1
# Out:
#  1 of kfold 10
# C-index: 0.59
# IBS: 0.19
#
#  2 of kfold 10
# C-index: 0.70
# IBS: 0.19
#
#  3 of kfold 10
# C-index: 0.62
# IBS: 0.16
#
#  4 of kfold 10
# C-index: 0.70
# IBS: 0.14
#
#  5 of kfold 10
# C-index: 0.89
# IBS: 0.12
#
#  6 of kfold 10
# C-index: 0.85
# IBS: 0.12
#
#  7 of kfold 10
# C-index: 0.91
# IBS: 0.11
#
#  8 of kfold 10
# C-index: 0.52
# IBS: 0.13
#
#  9 of kfold 10
# C-index: 0.55
# IBS: 0.20
#
#  10 of kfold 10
# C-index: 0.53
# IBS: 0.16

# %% [markdown]
# #### Below is an example on how to perform a grid search for the optimal RF parameters

# %%
num_tree=(10, 15, 20, 50, 100, 200)
max_depth=(1, 3, 5, 7, 9, 10, 20)
min_node=(2, 5, 10, 15, 20)

# %%
# this script searches the RF paramters listed in the cell 29
#prints out the average of 10 K Fold concordance
from sklearn.model_selection import StratifiedKFold
from pysurvival.models.survival_forest import RandomSurvivalForestModel
from pysurvival.utils.metrics import concordance_index
from statistics import mean 

for a in num_tree:
    for b in max_depth:
        for c in min_node:
            cc=[]
            kf=StratifiedKFold(n_splits=10, random_state=42, shuffle=True)
            i=1
            for train_index, test_index in kf.split(Xnew,Enew):
                X1_train, X1_test=Xnew.loc[train_index], Xnew.loc[test_index]
                X_train, X_test=X1_train[features2], X1_test[features2]
                T_train, T_test=X1_train['time column'].values, X1_test['time column'].values
                E_train, E_test=Enew.loc[train_index].values, Enew.loc[test_index].values
                xst = RandomSurvivalForestModel(num_trees=a) 
                xst.fit(X_train, T_train, E_train, max_features = 'sqrt', max_depth = b,
                min_node_size = c, num_threads = -1, 
                sample_size_pct = 0.63, importance_mode = 'normalized_permutation',
                seed = None, save_memory=False )
                from pysurvival.utils.metrics import concordance_index
                c_index = concordance_index(xst, X_test, T_test, E_test)
                cc.append(c_index)
                i=i+1
            print(a,b, c, mean(cc))
# Out:
# 10 1 2 0.6895374644740329
# 10 1 5 0.6315961892147324
# 10 1 10 0.662795187094711
# 10 1 15 0.6849230780820963
# 10 1 20 0.6951021596176218
# 10 3 2 0.6737797502844945
# 10 3 5 0.6806895790772239
# 10 3 10 0.6799231996092864
# 10 3 15 0.691437646452078
# 10 3 20 0.7005877043806584
# 10 5 2 0.6614226840311525
# 10 5 5 0.6778030224993347
# 10 5 10 0.656509761621987
# 10 5 15 0.6620713416706286
# 10 5 20 0.6904166664194418
# 10 7 2 0.6569949143608134
# 10 7 5 0.7004896263611023
# 10 7 10 0.6685965892050733
# 10 7 15 0.671258352026434
# 10 7 20 0.6533341120393048
# 10 9 2 0.6444629078579248
# 10 9 5 0.6470910780961919
# 10 9 10 0.6434221065539122
# 10 9 15 0.6991739192859582
# 10 9 20 0.6727068151350497
# 10 10 2 0.664289225079147
# 10 10 5 0.6733438309373599
# 10 10 10 0.673429487907068
# 10 10 15 0.6654290082916735
# 10 10 20 0.690314779462215
# 10 20 2 0.6091106648838204
# 10 20 5 0.6616356441653908
# 10 20 10 0.6878271710529018
# 10 20 15 0.6214639994716582
# 10 20 20 0.6903775666036245
# 15 1 2 0.6652090421517074
# 15 1 5 0.6661095951083639
# 15 1 10 0.6840933113930655
# 15 1 15 0.6802255769580434
# 15 1 20 0.6919491556925942
# 15 3 2 0.7362809638701875
# 15 3 5 0.6582151067131073
# 15 3 10 0.6966812305699492
# 15 3 15 0.7040840907259093
# 15 3 20 0.6931254294738979
# 15 5 2 0.6472644409078654
# 15 5 5 0.6436585339135189
# 15 5 10 0.6828738568967876
# 15 5 15 0.6655067589997815
# 15 5 20 0.693352988745692
# 15 7 2 0.6424832168621764
# 15 7 5 0.6546086056833632
# 15 7 10 0.663871979603667
# 15 7 15 0.673898783855332
# 15 7 20 0.6769141597311342
# 15 9 2 0.6921110667248453
# 15 9 5 0.6515808823185573
# 15 9 10 0.6300020076390749
# 15 9 15 0.6834269678935174
# 15 9 20 0.6786293352920131
# 15 10 2 0.6038572259374312
# 15 10 5 0.6894553790002316
# 15 10 10 0.6871813442907524
# 15 10 15 0.6694906364527672
# 15 10 20 0.6921439948870777
# 15 20 2 0.6457178772871843
# 15 20 5 0.66329716528435
# 15 20 10 0.7060877559491227
# 15 20 15 0.6962887476408539
# 15 20 20 0.6686898942274078
# 20 1 2 0.6551795684209846
# 20 1 5 0.657370130655679
# 20 1 10 0.6805541167173647
# 20 1 15 0.7080201785656809
# 20 1 20 0.6519925320975668
# 20 3 2 0.6805012746442544
# 20 3 5 0.6776889278951007
# 20 3 10 0.7104271301251809
# 20 3 15 0.6507765877569172
# 20 3 20 0.6369339760848662
# 20 5 2 0.6903626681696291
# 20 5 5 0.6847920525355633
# 20 5 10 0.6693384598934712
# 20 5 15 0.7141133286405043
# 20 5 20 0.730462733212699
# 20 7 2 0.6269609480676384
# 20 7 5 0.5977527830585203
# 20 7 10 0.7031722227061267
# 20 7 15 0.695868530275426
# 20 7 20 0.6747974332312981
# 20 9 2 0.6707133290536557
# 20 9 5 0.6408717956616916
# 20 9 10 0.702056886741659
# 20 9 15 0.7190973968420775
# 20 9 20 0.6683656622563551
# 20 10 2 0.6518556232352829
# 20 10 5 0.7044214160570565
# 20 10 10 0.6579226231883556
# 20 10 15 0.6832711281604452
# 20 10 20 0.6768994963212133
# 20 20 2 0.6651613299874647
# 20 20 5 0.6846548089336149
# 20 20 10 0.6550620802301917
# 20 20 15 0.6290988654360081
# 20 20 20 0.6774955268322492
# 50 1 2 0.6704411642367648
# 50 1 5 0.6466129449270087
# 50 1 10 0.6866072946623574
# 50 1 15 0.6530060905611196
# 50 1 20 0.723086211287837
# 50 3 2 0.6850205066547917
# 50 3 5 0.642332892262036
# 50 3 10 0.6647110025438133
# 50 3 15 0.6568562960420558
# 50 3 20 0.6960583689407308
# 50 5 2 0.6489879854020053
# 50 5 5 0.6410703449602538
# 50 5 10 0.6581485937732237
# 50 5 15 0.6742939704067153
# 50 5 20 0.6588433293032638
# 50 7 2 0.6426820433279903
# 50 7 5 0.645515379497503
# 50 7 10 0.6967961802621653
# 50 7 15 0.6624508023970784
# 50 7 20 0.6716906664289795
# 50 9 2 0.6634698665943495
# 50 9 5 0.6670555641698644
# 50 9 10 0.6958993739331487
# 50 9 15 0.6526331691315345
# 50 9 20 0.7039580049598225
# 50 10 2 0.6540326999531466
# 50 10 5 0.6313088600251548
# 50 10 10 0.693549412029747
# 50 10 15 0.7065641054690189
# 50 10 20 0.6965134053037491
# 50 20 2 0.6211619570406156
# 50 20 5 0.7092544930092094
# 50 20 10 0.6761905318566948
# 50 20 15 0.6808360840215502
# 50 20 20 0.6926204877500463
# 100 1 2 0.6691340890106923
# 100 1 5 0.6878848752263067
# 100 1 10 0.6909572506076975
# 100 1 15 0.6887710950173832
# 100 1 20 0.6881425611052304
# 100 3 2 0.6974592132016884
# 100 3 5 0.6549924339480201
# 100 3 10 0.6626886048638323
# 100 3 15 0.6665052175855898
# 100 3 20 0.6746438194271702
# 100 5 2 0.6508196204392386
# 100 5 5 0.6599950513115964
# 100 5 10 0.7007451195373543
# 100 5 15 0.7006325390001021
# 100 5 20 0.6880724545892032
# 100 7 2 0.6475057005704481
# 100 7 5 0.6656435417633474
# 100 7 10 0.6527108079112542
# 100 7 15 0.6706964702738766
# 100 7 20 0.6859958892368706
# 100 9 2 0.6857875635418801
# 100 9 5 0.659880314382083
# 100 9 10 0.6926375284166085
# 100 9 15 0.6613839549370073
# 100 9 20 0.680679897490448
# 100 10 2 0.6347530240550043
# 100 10 5 0.643705011017207
# 100 10 10 0.6834624650132677
# 100 10 15 0.6927081504508759
# 100 10 20 0.6918376663620152
# 100 20 2 0.6355298055262558
# 100 20 5 0.6938267988056516
# 100 20 10 0.6833133716792018
# 100 20 15 0.6944868929448339
# 100 20 20 0.6978569942899494
# 200 1 2 0.6686792651122355
# 200 1 5 0.6606302769519424
# 200 1 10 0.6874207321815264
# 200 1 15 0.6526351662176803
# 200 1 20 0.6857892431139468
# 200 3 2 0.657678822681874
# 200 3 5 0.6679189307012398
# 200 3 10 0.6898622918999489
# 200 3 15 0.6772132604926752
# 200 3 20 0.6822774334683143
# 200 5 2 0.6550482332957501
# 200 5 5 0.6852818705089243
# 200 5 10 0.6711044496320182
# 200 5 15 0.6869456841456532
# 200 5 20 0.7008736109125223
# 200 7 2 0.6835428382978056
# 200 7 5 0.6828467628632524
# 200 7 10 0.6944366388815133
# 200 7 15 0.6890949095480142
# 200 7 20 0.6801856483427583
# 200 9 2 0.654320151110684
# 200 9 5 0.680099098311082
# 200 9 10 0.693982583179367
# 200 9 15 0.6678279000591281
# 200 9 20 0.6837267565751116
# 200 10 2 0.6623521607520587
# 200 10 5 0.6951251510617971
# 200 10 10 0.6775202773889494
# 200 10 15 0.7108743260547317
# 200 10 20 0.6899301381755398
# 200 20 2 0.647304741595869
# 200 20 5 0.6700661068209999
# 200 20 10 0.6821986447525347
# 200 20 15 0.6959446467658021
# 200 20 20 0.6856271864483418
